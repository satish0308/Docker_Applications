# %%
from pyspark.sql import SparkSession
import pyspark.pandas as pdf
from pyspark import SparkConf,SparkContext
import sys


def call_main():
    spark=SparkSession.builder.master("local").appName("demo").getOrCreate()
    df=spark.read.json(sys.argv[1])
    df2=df.select('user_id','friends')
    print(sys.argv[2])
    print('satish')
    df3=df2.repartition(5)
    df3.write.option("header","true").mode('overwrite').csv(sys.argv[2])

    

if __name__=="__main__":
    call_main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/spark/python/pyspark/sql/pandas/utils.py:53, in require_minimum_pyarrow_version()
#      52 try:
# ---> 53     import pyarrow
#      55     have_arrow = True
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 import pyspark.pandas as pdf
#       3 from pyspark import SparkConf,SparkContext
#       4 import sys
#
# File /opt/spark/python/pyspark/pandas/__init__.py:35
#      33 try:
#      34     require_minimum_pandas_version()
# ---> 35     require_minimum_pyarrow_version()
#      36 except ImportError as e:
#      37     if os.environ.get("SPARK_TESTING"):
#
# File /opt/spark/python/pyspark/sql/pandas/utils.py:60, in require_minimum_pyarrow_version()
#      58     raised_error = error
#      59 if not have_arrow:
# ---> 60     raise ImportError(
#      61         "PyArrow >= %s must be installed; however, "
#      62         "it was not found." % minimum_pyarrow_version
#      63     ) from raised_error
#      64 if LooseVersion(pyarrow.__version__) < LooseVersion(minimum_pyarrow_version):
#      65     raise ImportError(
#      66         "PyArrow >= %s must be installed; however, "
#      67         "your version was %s." % (minimum_pyarrow_version, pyarrow.__version__)
#      68     )
#
# ImportError: PyArrow >= 4.0.0 must be installed; however, it was not found.
